# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pf=pd.read_csv("C:\\Users\EDGER\Desktop\plphac\heart+disease\switzerland.data")
# Display the first few rows of the dataset
print(pf.head())
print(pf.info())
# Check for missing values
print(pf.isnull().sum())
# Fill missing values with the column mean (if any)
pf.fillna(pf.mean(), inplace=True)
# Compute basic statistics for numerical columns
print(pf.describe())
# Group by 'species' and compute mean of numerical columns
grouped = pf.groupby('species').mean()
print(grouped)

# Example of a line chart (assumed dataset with 'date' and 'sales')
pf['date'] = pd.to_datetime(df['date']) 
plt.plot(pf['date'], pf['sales'])
plt.title('Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# Bar chart to compare average petal length across species
plt.figure(figsize=(8,6))
sns.barplot(x='species', y='petal length (cm)', data=pf)
plt.title('Average Petal Length per Species')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.show()

# Histogram of sepal length distribution
plt.figure(figsize=(8,6))
sns.histplot(pf['sepal length (cm)'], kde=True, bins=20)
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# Scatter plot of sepal length vs. petal length
plt.figure(figsize=(8,6))
sns.scatterplot(x='sepal length (cm)', y='petal length (cm)', data=df, hue='species')
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend(title='Species')
plt.show()

try:
    # Try loading the dataset
    pf = pd.read_csv("C:\\Users\EDGER\Desktop\plphac\heart+disease\switzerland.data")
except FileNotFoundError:
    print("The file was not found. Please check the file path.")
except pd.errors.EmptyDataError:
    print("The file is empty. Please check the file content.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\EDGER\AppData\Local\Temp\ipykernel_13404\3121399627.py:3: SyntaxWarning: invalid escape sequence '\E'
#   pf=pd.read_csv("C:\\Users\EDGER\Desktop\plphac\heart+disease\switzerland.data")
# Matplotlib is building the font cache; this may take a moment.
#          3001 0 65 1 1 1 1
# 0    -9 4 115 0 0 -9 -9 -9
# 1       0 -9 -9 0 1 9 85 0
# 2    1 1 0 1 12 8.3 -9 100
# 3  93 56 185 80 115 70 1 0
# 4    0 2 -9 -9 -9 -9 -9 -9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1229 entries, 0 to 1228
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   3001 0 65 1 1 1 1  1229 non-null   object
# dtypes: object(1)
# memory usage: 9.7+ KB
# None
# 3001 0 65 1 1 1 1    0
# dtype: int64
# ---------------------------------------------------------------------------
# ...
